# %%
import json
import csv
import pandas as pd

# %%
# !gdown --id 1PCxDbBdU53Qs9HL_sjZPQj0asabPJbCK
# !gdown --id 1Bo-K1PbEeNQ-Aij6b-D0wlLMjknh9Z-I
# !gdown --id 1xMh1gsZVadS7aZPqr5-_WHBzk4TPA3zD
# !gdown --id 1-AvzpI8nzg_AOC4gIyabROi8_CniNl-t
# !gdown --id 1GY19664wdmaUmJgK8WASXJM0M-L5V_Jf
# !gdown --id 1e5S0fNfvcZPmHQOfNAUr-DkSDKD5xTfd
# !gdown --id 1kYsjlHxToJ8OuwcP1HNWoKdwPEuP26zt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1PCxDbBdU53Qs9HL_sjZPQj0asabPJbCK
# To: /content/0_TheNewYorkTime.csv
# 16.4MB [00:00, 137MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Bo-K1PbEeNQ-Aij6b-D0wlLMjknh9Z-I
# To: /content/0-TheSunTime.csv
# 12.8MB [00:00, 48.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1xMh1gsZVadS7aZPqr5-_WHBzk4TPA3zD
# To: /content/1_TheBeaverton_v2.csv
# 5.67MB [00:00, 11.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-AvzpI8nzg_AOC4gIyabROi8_CniNl-t
# To: /content/1_TheBeaverton.csv
# 10.6MB [00:00, 29.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1GY19664wdmaUmJgK8WASXJM0M-L5V_Jf
# To: /content/1_TheBurrardStreetJournal.csv
# 100% 101k/101k [00:00<00:00, 37.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1e5S0fNfvcZPmHQOfNAUr-DkSDKD5xTfd
# To: /content/1_TheDailySquib.csv
# 2.12MB [00:00, 67.5MB/s]
# Downloading...
# ...

# %%
# !gdown --id 1C0xT4IvG-dxrumjHedMTCDiBXsilYQBV
# !gdown --id 1KUZGtUFZU0FZtKFWjRx1Hsl7LijMjk8-
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1C0xT4IvG-dxrumjHedMTCDiBXsilYQBV
# To: /content/Test_1_add_NewsBiscuit.csv
# 100% 719k/719k [00:00<00:00, 103MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1KUZGtUFZU0FZtKFWjRx1Hsl7LijMjk8-
# To: /content/Test_1_add_TheTrueNorthTime.csv
# 100% 146k/146k [00:00<00:00, 50.7MB/s]
# Permission denied: https://drive.google.com/uc?id=1yTMap-04taxBcdwbxiaH4yKKJPJjidev
# Maybe you need to change permission over 'Anyone with the link'?

# %%
df_1 = pd.read_csv("/content/Test_1_add_NewsBiscuit.csv", usecols=['headline', 'is_sarcastic', 'article_link'])
df_3 = pd.read_csv("/content/Test_1_add_TheTrueNorthTime.csv", usecols=['headline', 'is_sarcastic', 'article_link'])

df_1 = df_1[['is_sarcastic', 'headline', 'article_link']]
df_3 = df_3[['is_sarcastic', 'headline', 'article_link']]

df_1 = df_1.rename(columns = {'headline': 'title'})
df_3 = df_3.rename(columns = {'headline': 'title'})


df_1
# Out:
#       is_sarcastic  ...                                       article_link
# 0                1  ...  http://www.newsbiscuit.com/2021/06/07/southgat...
# 1                1  ...  http://www.newsbiscuit.com/2021/06/06/hospital...
# 2                1  ...  http://www.newsbiscuit.com/2021/06/06/china-sa...
# 3                1  ...  http://www.newsbiscuit.com/2021/06/06/top-gear...
# 4                1  ...  http://www.newsbiscuit.com/2021/06/06/british-...
# ...            ...  ...                                                ...
# 4446             1  ...  http://www.newsbiscuit.com/2018/01/01/sporting...
# 4447             1  ...  http://www.newsbiscuit.com/2017/12/31/despacit...
# 4448             1  ...  http://www.newsbiscuit.com/2017/12/31/argos-ur...
# 4449             1  ...  http://www.newsbiscuit.com/2017/12/31/catholic...
# 4450             1  ...  http://www.newsbiscuit.com/2017/12/31/58-year-...
#
# [4451 rows x 3 columns]

# %%
df_2 = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/Machine Learning/31062021_sarcasm-detection/dataset/Sarcasm_Detection_upTest.csv")
df_1 = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/Machine Learning/31062021_sarcasm-detection/dataset/1-TheOnion.csv")
df_123 = df_1.append(df_2)

df_123 = df_123.sample(frac = 1).reset_index(drop=True)

df_123
# Out:
#        is_sarcastic  ...                                       article_link
# 0                 0  ...  https://www.mirror.co.uk/news/uk-news/embarras...
# 1                 1  ...  https://www.theonion.com/man-takes-solace-in-f...
# 2                 1  ...  https://www.theonion.com/man-takes-solace-in-f...
# 3                 0  ...  https://www.mirror.co.uk/news/uk-news/elderly-...
# 4                 0  ...  https://www.mirror.co.uk/news/uk-news/mum-whos...
# ...             ...  ...                                                ...
# 42153             0  ...  https://www.mirror.co.uk/news/uk-news/ian-brad...
# 42154             0  ...  https://www.mirror.co.uk/news/uk-news/go-hero-...
# 42155             0  ...  https://www.mirror.co.uk/news/uk-news/sainsbur...
# 42156             1  ...  https://www.theonion.com/senate-votes-to-make-...
# 42157             0  ...  https://www.mirror.co.uk/news/uk-news/daredevi...
#
# [42158 rows x 3 columns]

# %%
df_123.to_csv("/content/gdrive/MyDrive/Colab Notebooks/Machine Learning/31062021_sarcasm-detection/dataset/Sarcasm_Detection_upTest.csv", header=True, index=False)

# %%
# !gdown --id 15oPD7wrKUH-El1kazWF8gsPSHhnmquQf
# !gdown --id 1WrjBDQFDMNyPFFbkXTHElDdUvlPb2ikM
# !gdown --id 1g3m0gkO8YQ5PTfT_x4Wx00ZUxLX3Gz7C
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15oPD7wrKUH-El1kazWF8gsPSHhnmquQf
# To: /content/1-dailybonnet.csv
# 100% 311k/311k [00:00<00:00, 45.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1WrjBDQFDMNyPFFbkXTHElDdUvlPb2ikM
# To: /content/1-NewsThump.csv
# 4.51MB [00:00, 35.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1g3m0gkO8YQ5PTfT_x4Wx00ZUxLX3Gz7C
# To: /content/1-TheCivilian.csv
# 100% 117k/117k [00:00<00:00, 45.2MB/s]

# %%
df_tr1 = pd.read_csv("/content/1-NewsThump.csv")
df_tr3 = pd.read_csv("/content/1-TheCivilian.csv")
df_tr4 = pd.read_csv("/content/1-dailybonnet.csv")
df_tr2 = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/Machine Learning/31062021_sarcasm-detection/dataset/Sarcasm_Detection_Train.csv")

df_tr = df_tr1.append(df_tr2)
df_tr.append(df_tr3)
df_tr.append(df_tr4)


df_tr = df_tr.sample(frac = 1).reset_index(drop=True)

df_tr
# Out:
#         is_sarcastic  ...                                       article_link
# 0                  0  ...  https://www.thetimes.co.uk/article/coronavirus...
# 1                  1  ...  https://newsthump.com/2016/04/08/everyone-defi...
# 2                  1  ...  https://thebeaverton.com/2019/09/watch-season-...
# 3                  1  ...  https://newsthump.com/2021/05/11/keir-starmer-...
# 4                  0  ...  https://www.thetimes.co.uk/article/rightmove-t...
# ...              ...  ...                                                ...
# 430137             1  ...  https://thebeaverton.com/2015/10/ndp-claim-lib...
# 430138             0  ...  https://www.nytimes.com/2020/08/16/world/europ...
# 430139             1  ...  https://thebeaverton.com/2021/06/man-daydreams...
# 430140             0  ...  https://www.thetimes.co.uk/article/airlines-mu...
# 430141             1  ...  https://www.betootaadvocate.com/uncategorized/...
#
# [430142 rows x 3 columns]

# %%
df_tr.to_csv("/content/gdrive/MyDrive/Colab Notebooks/Machine Learning/31062021_sarcasm-detection/dataset/Sarcasm_Detection_upTrain.csv", header=True, index=False)

# %%
df_t1 = pd.read_csv("/content/Test_0_TheMirror.csv")
df_t2 = pd.read_csv("/content/Test_1_TheDailyEr.csv")

df = df_t1.append(df_t2)

df = df.sample(frac = 1).reset_index(drop=True)


df
# Out:
#        is_sarcastic  ...                                       article_link
# 0                 0  ...  https://www.mirror.co.uk/news/uk-news/mum-woke...
# 1                 0  ...  https://www.mirror.co.uk/news/uk-news/dog-owne...
# 2                 0  ...  https://www.mirror.co.uk/news/uk-news/latest-t...
# 3                 0  ...  https://www.mirror.co.uk/news/uk-news/kate-mid...
# 4                 0  ...  https://www.mirror.co.uk/news/uk-news/violent-...
# ...             ...  ...                                                ...
# 28202             1  ...  http://thedailyer.com/student-panic-things-goi...
# 28203             0  ...  https://www.mirror.co.uk/news/uk-news/girl-10-...
# 28204             0  ...  https://www.mirror.co.uk/news/uk-news/real-lif...
# 28205             0  ...  https://www.mirror.co.uk/news/uk-news/furious-...
# 28206             0  ...  https://www.mirror.co.uk/news/uk-news/man-who-...
#
# [28207 rows x 3 columns]

# %%
df1 = pd.read_csv("/content/1_TheBurrardStreetJournal.csv")
df2 = pd.read_csv("/content/1_TheBeaverton.csv")
df3 = pd.read_csv("/content/0-TheSunTime.csv")
df4 = pd.read_csv("/content/0_TheNewYorkTime.csv")
df5 = pd.read_csv("/content/1_TheDailySquib.csv")
df6 = pd.read_csv("/content/1_TheBeaverton_v2.csv")
df7 = pd.read_csv("/content/0_NewsWeek.csv")

df1 = df1.drop(columns=['publishdate'])
df2 = df2.drop(columns=['publishdate'])
df3 = df3.drop(columns=['publishdate'])

df_v1 = df1.append(df2)
df_v1.append(df3)
df_v1.append(df4)

df_v2 = df5.append(df6)
df_v2.append(df7)
# Out:
#        is_sarcastic  ...                                       article_link
# 0                 1  ...  https://www.dailysquib.co.uk/world/42521-joe-b...
# 1                 1  ...  https://www.dailysquib.co.uk/world/42476-honou...
# 2                 1  ...  https://www.dailysquib.co.uk/world/42446-why-i...
# 3                 1  ...  https://www.dailysquib.co.uk/world/42443-trans...
# 4                 1  ...  https://www.dailysquib.co.uk/world/42417-das-b...
# ...             ...  ...                                                ...
# 42093             0  ...  https://www.newsweek.com/camille-cosby-bill-co...
# 42094             0  ...  https://www.newsweek.com/man-holding-cellphone...
# 42095             0  ...  https://www.newsweek.com/obama-meet-attorney-g...
# 42096             0  ...  https://www.newsweek.com/new-year-brings-minim...
# 42097             0  ...  https://www.newsweek.com/southern-states-brace...
#
# [89138 rows x 3 columns]

# %%
df_v1 = df_v1.sample(frac = 1).reset_index(drop=True)

df_v2 = df_v2.sample(frac = 1).reset_index(drop=True)

df_v1.to_csv("/content/df_v1.csv")
df_v2.to_csv("/content/df_v2.csv")

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df_test.to_csv("/content/gdrive/MyDrive/Colab Notebooks/Machine Learning/31062021_sarcasm-detection/dataset/Sarcasm_Detection_Test.csv", header=True, index=False)

#df.to_csv("/content/gdrive/MyDrive/Colab Notebooks/Machine Learning/31062021_sarcasm-detection/dataset/Sarcasm_Detection.csv", header=True, index=False)

# %%
# https://pythonexamples.org/python-csv-to-json/
def csv_to_json(csvFilePath, jsonFilePath):
    jsonArray = []
      
    #read csv file
    with open(csvFilePath, encoding='utf-8') as csvf: 
        #load csv file data using csv library's dictionary reader
        csvReader = csv.DictReader(csvf) 

        #convert each csv row into python dict
        for row in csvReader: 
            #add this python dict to json array
            jsonArray.append(row)
  
    #convert python jsonArray to JSON String and write to file
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonString = json.dumps(jsonArray, indent=4)
        jsonf.write(jsonString)
          
csvFilePath = r"/content/df_v1.csv"
jsonFilePath = r"/content/Sarcasm_Detection_v1.json"
csv_to_json(csvFilePath, jsonFilePath)

csvFilePath = r"/content/df_v2.csv"
jsonFilePath = r"/content/Sarcasm_Detection_v2.json"
csv_to_json(csvFilePath, jsonFilePath)

# %%
with open("/content/abc.json", "r") as fin:
    data = json.load(fin)
print(data[1])
# Out:
# {'is_sarcastic': '1', 'title': 'Donald Trump Jr. Tests Positive For Being A Dipshit', 'article_link': 'https://www.burrardstreetjournal.com/donald-trump-jr-tests-positive-for-being-a-dipshit/', 'publishdate': '2021-01-20T15:48:36+00:00'}
